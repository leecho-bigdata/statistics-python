# %% [markdown]
# # 17_2.Chi-square test(적합성)(연습문제)
# - https://www.statsmodels.org/devel/contingency_tables.html

# %% [markdown]
# ## 1.기본 package 설정

# %%
# 1.기본
import numpy as np  # numpy 패키지 가져오기
import matplotlib.pyplot as plt # 시각화 패키지 가져오기
import seaborn as sns # 시각화

# 2.데이터 가져오기
import pandas as pd # csv -> dataframe으로 전환

# 3.통계분석 package
#import pingouin as pg
from scipy import stats
import statsmodels.api as sm

# %% [markdown]
# ## 2.데이터 불러오기

# %% [markdown]
# ### 2.1 데이터 프레임으로 저장
# - 원본데이터(csv)를 dataframe 형태로 가져오기(pandas)

# %%
god_df = pd.read_csv('https://raw.githubusercontent.com/leecho-bigdata/statistics-python/main/17_2.ohl.csv', encoding="cp949")
god_df
# Out:
#    종류  관찰수   판매비율
# 0  Q1  147  0.237
# 1  Q2  110  0.259
# 2  Q3   52  0.259
# 3  Q4   50  0.245

# %% [markdown]
# ## 3.Chi-square test(적합도)

# %% [markdown]
# ### 3.1 분할표(contingency table)

# %%
observed = god_df['관찰수']
expected = god_df['관찰수'].sum() * god_df['판매비율']

# %%
np.array(observed)
np.array(expected)
# Out:
# array([85.083, 92.981, 92.981, 87.955])

# %%
stats.chisquare(f_obs=observed, f_exp=expected)
# Out:
# Power_divergenceResult(statistic=82.6144790552302, pvalue=8.435805477096608e-18)
